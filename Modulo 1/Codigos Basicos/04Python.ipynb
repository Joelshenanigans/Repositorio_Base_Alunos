# %% [markdown]
# # Operadores relacionais

# %% [markdown]
# ##> maior
# ##>= maior igual
# ##< menor
# ##< menor igual
# ##!= diferente
# ##== igual

# %%
10 > 20 # 10 é maior que 20, portanto falso
# Out:
# False

# %%
10 < 20 # 10 é menor que 20, portanto verdadeiro
# Out:
# True

# %%
5+1 != 6 # 5+1 é diferente de 6 (falso)
# Out:
# False

# %%
3+1 >= 4 # 3+1 é igual a 4 (verdade)
# Out:
# True

# %%
10 != 10 # 10 nao é diferente dele mesmo
# Out:
# False

# %%
nome_aluno = "Joel"
nome_aluno = "carlos"

# %%
nome_aluno == nome_professor
# Out:
# False

# %% [markdown]
# # Operadores Lógicos

# %% [markdown]
# 1. AND(e)
# 2. OR(ou)
# 3. NOT(negação)

# %% [markdown]
# ## AND
#
#
#
# 1. true + true = true
# 2. true + false = false
# 3. false + false = false
# 4. false + true = false

# %%
(10>20) and (20>30) # false + false = false
# Out:
# False

# %%
(10>20) and (20<30)

# %% [markdown]
# # OR
#
#
#
# 1. true + true = true
# 2. true + false = true
# 3. false + true = true
# 4. false + false = false

# %%
(1<2) or (3>6)
# Out:
# True

# %%
"joao" == "joao" or "python" != "python"
# Out:
# True

# %% [markdown]
# # NOT
#
# 1. not true = false
# 2. not false = true

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True
