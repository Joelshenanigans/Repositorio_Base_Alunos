# %% [markdown]
# # String

# %% [markdown]
# São usadas principalmente para armazenar informações do texto. Nelas temos uma sequência de caracteres que formam um texto. O python permite formar strings com aspas simples ou duplas

# %%
"João==JOÃO" # o python diferencia letras maiusculas de minusculas
# Out:
# 'João == JOÃO'

# %%
nome = "Felipe"
sobrenome = "Joel"

# %%
print(nome)
# Out:
# Felipe

# %% [markdown]
# # F-strings

# %% [markdown]
# String literais formatadas

# %%
idade = 20

# %%
print(nome, sobrenome, idade) # as virgulas sao maneiras de chamar variaveis diferentes
# Out:
# Felipe Joel 20

# %%
print(f"{nome} {sobrenome} tem {idade} anos.") # f na frente informa que estamos formatando o print
# Out:
# Felipe Joel tem 20 anos.

# %%
linguajem = "Python"
print(f"Eu adoro programar em {linguajem}. E amo mais ainda ganhar muito $$ programando em Python.")
# Out:
# Eu adoro programar em Python. E amo mais ainda ganhar muito $$ programando em Python.

# %% [markdown]
# # String são objetos iteráveis

# %%
nome = "felipe" # o python entende uma palavra como uma lista de letras, então podemos percorrer
# essa lista e capturar os elementos que desejamos
# uma lista sempre inicia pelo indice zero

# %%
print(nome)
# Out:
# felipe

# %%
nome[0]
# Out:
# 'f'

# %%
nome[3]
# Out:
# 'i'

# %%
nome[-1] # podemos acessar o ultimo elemento de uma lista atraves do indice
# Out:
# 'e'

# %% [markdown]
# ## Entrada de dados com a função input()

# %% [markdown]
# É muito comum em programação que o usuário passe algum tipo de dado

# %%
input("diigite seu nome: ")
# Out:
# diigite seu nome: Joel
# 'Joel'

# %%
nome = input("digite seu nome: ")
# Out:
# digite seu nome: Joel

# %%
print(nome)
# Out:
# Joel

# %%
# para fazer operaçao matematica precisamos informar qual tipo é o dado
num1 = input("digite um stand ")
num2 = input("digite outro stand: ")
# Out:
# digite um stand za warudo
# digite outro stand: za hando

# %%
num1 =int(input("digite um numero: "))
num2 =int(input("digite outro numero: "))
print(num1 + num2)
# Out:
# digite um numero: 5
# digite outro numero: 7
# 12

# %%
soma = num1 + num2
print(soma)
# Out:
# 12

# %%
nota1 = float(input("digite a primeira nota: "))
nota2 = float(input("digite a segunda nota: "))
media =(nota1 + nota2)/2
print(f"O aluno(a) teve notas {nota1}, {nota2} e sua media é {media}. ")
# Out:
# digite a primeira nota: 1.0
# digite a segunda nota: 2.0
# O aluno(a) teve notas 1.0, 2.0 e sua media é 1.5.

# %% [markdown]
# # Operadores Aritmeticos

# %% [markdown]
# Adição(+)

# %%
print(10 + 20)
print(10 + 20.5)
print(10 + 30 + 40)
# Out:
# 30
# 30.5
# 80

# %%
print(-89 + 63) #print() é uma função de saída no python
print(23 - 17) #23 + (-17)
print(23 + (-17))
print(34 - 67)
# Out:
# -26
# 6
# 6
# -33

# %%
print(123-87)
# Out:
# 36

# %% [markdown]
# Multiplicação (*)

# %%
print(10*2)
# Out:
# 20

# %%
print(2.4 * 2.5)
# Out:
# 6.0

# %% [markdown]
# Divisão(/)

# %%
print(1000/10)
print(129/23)
# Out:
# 100.0
# 5.608695652173913

# %% [markdown]
# Divisão com resultado inteiro(//)

# %%
print(129//23) # com "//" é o numero inteiro apenas
# Out:
# 5

# %% [markdown]
# Exponenciação

# %%
print(2**3)
# Out:
# 8

# %%
print(2**-1)
# Out:
# 0.5

# %%
print(2**-1.5)
# Out:
# 0.3535533905932738

# %% [markdown]
# #Precedência

# %% [markdown]
# 1. Parênteses
# 2. Expoentes
# 3. Multiplicação
# 4. Divisão (da esquerda para a direita)
# 5. Somas e subtração

# %%
5 + 25 * 2
# Out:
# 55

# %%
(5 + 25) * 2
# Out:
# 60

# %%
(12 + 3 - 1 * 50/3)
# Out:
# -1.6666666666666679

# %% [markdown]
# Radiaciação

# %%
4 ** 0.5
# Out:
# 2.0

# %% [markdown]
# # Hora da Prática

# %% [markdown]
# 1) Crie um código que receba o nome do aluno, duas notas e informe a média do aluno. Obs: no seu print você deve apresentar o nome do aluno, as duas notas e a média

# %%
nome1 = input("digite seu nome")
idade = input("digite sua idade")
nota1 = float(input("digite um numero: "))
nota2 = float(input("digite um numero: "))
media = (nota1 + nota2)/2
print(f"O aluno(a) teve notas {nota1}, {nota2} e sua media é {media}. ")
# Out:
# digite seu nomeJoel
# digite sua idade16
# digite um numero: 6.0
# digite um numero: 7.0
# O aluno(a) teve notas 6.0, 7.0 e sua media é 6.5.

# %% [markdown]
# 2) Código que receba as médidas de um retângulo e informe o perimetro do mesmo

# %%
medida1 = float(input("digite a medida1 do retangulo: ")) # float para números decimais
medida2 = float(input("digite a medida2 do retangulo: "))
perimetro = (medida1 + medida2)*2
print(f"o primetro do retangulo é {perimetro}")
# Out:
# digite a medida1 do retangulo: 8.5
# digite a medida2 do retangulo: 6.5
# o primetro do retangulo é 30.0

# %% [markdown]
# 3) Código que calcule a raiz quadrada de um número

# %%
num1 = int(input("Digite um numero")) # int é usado para numeros inteiros
raiz = num1 **0.5
print(f"A raiz quadrada de {num1} é igual a {raiz}")
# Out:
# Digite um numero64
# A raiz quadrada de 64 é igual a 8.0

# %% [markdown]
# 4) Crie uma calculadora(multiplicação, divisão, subtração e adição). O código deve receber 2 números e apresentar o resultado das 4 operações

# %%
n1 = int(input("digite um numero:"))
n2 = int(input("digite um numero:"))
soma1 = n1 + n2
subtracao1 = n1 - n2
multiplicacao1 = n1 * n2
subtracao1 = n1/n2
print(f"o resultado das contas é {soma1} {subtracao1} {multiplicacao1} {subtracao1}")
# Out:
# digite um numero:10
# digite um numero:10
# o resultado das contas é 20 1.0 100 1.0

# %% [markdown]
# 5) Calcule a diferença entre dois números

# %%
medida1 = float(input("digite a medida1 do retangulo: ")) # float para números decimais
medida2 = float(input("digite a medida2 do retangulo: "))
zangetsu = (medida1 - medida2)
print(f"o primetro do retangulo é {zangetsu}")
# Out:
# digite a medida1 do retangulo: 10
# digite a medida2 do retangulo: 15
# o primetro do retangulo é -5.0

# %% [markdown]
# 6) Calcule o produto entre dois números

# %%
medida1 = float(input("digite a medida1 do retangulo: ")) # float para números decimais
medida2 = float(input("digite a medida2 do retangulo: "))
zangetsu = (medida1 - medida2)
print(f"o primetro do retangulo é {zangetsu}")

# %% [markdown]
# 7) Crie um código que receba uma base e depois o expoente e calcule a potencia

# %% [markdown]
# 8) Crie um programa que solicite ao usuário a quantidade de horas trabalhadas por semana e o valor da hora de trabalho e calcule o salário mensa
